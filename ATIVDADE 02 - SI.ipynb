# %% [markdown]
# # Atividade 2 - Pré-Processamento
# - José Maria dos Santos Leal
# - Pedro Hércules de Sousa Dantas
# - Marcos Paulo Fontes Leal

# %% [markdown]
# ## Importando as bibliotecas

# %%
import pandas as pd
import numpy as np
import os
from sklearn.impute import SimpleImputer 
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pickle
import requests
import matplotlib.pyplot as plt

# %% [markdown]
# ## Carregando os dados

# %%
DATASET_PATH = '/Users/JOSE MARIA/Downloads/6° periodo/Sistemas inteligentes'

# %%
DATASET_NAME = 'Covid_piaui.csv'

# %%
def load_data(dataset_path, dataset_name):
    csv_path = os.path.join(dataset_path, dataset_name)
    return pd.read_csv(csv_path)

# %%
data = load_data(DATASET_PATH, DATASET_NAME)

# %%
data = data.drop('is_last', axis=1)
data = data.drop('state', axis=1)
data = data.drop('place_type', axis=1)
data = data.drop('Unnamed: 0', axis=1)
data = data.drop('date', axis=1)

# %%
data_alvo = data['deaths'].copy()

# %%
data = data.drop('deaths', axis=1)

# %%
data_alvo
# Out:
# 0       1
# 1       3
# 2       9
# 3       5
# 4      13
#        ..
# 219     1
# 220     9
# 221     0
# 222     3
# 223    56
# Name: deaths, Length: 224, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224 entries, 0 to 223
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   city                            224 non-null    object
#  1   confirmed                       224 non-null    int64
#  2   order_for_place                 224 non-null    int64
#  3   estimated_population_2019       224 non-null    float64
#  4   estimated_population            224 non-null    float64
#  5   city_ibge_code                  224 non-null    float64
#  6   confirmed_per_100k_inhabitants  224 non-null    float64
#  7   death_rate                      224 non-null    float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 14.1+ KB

# %%
cidades = data['city'].values

# %%
latitudes = []
longitudes = []
for cidade in cidades:
    request = 'https://nominatim.openstreetmap.org/search?city='+cidade+'&state=Piaui&format=json'
    response = requests.get(request)
    response_data = response.json()[0]
    
    latitude = float(response_data["lat"])
    longitude = float(response_data["lon"])
    latitudes.append(latitude)
    longitudes.append(longitude)

# %%
data['latitude'] = latitudes

# %%
data['longitude'] = longitudes

# %%
data
# Out:
#                    city  confirmed  order_for_place  \
# 0                 Acauã        175              329
# 1          Agricolândia        332              321
# 2    Alagoinha do Piauí        256              335
# 3     Alegrete do Piauí        460              317
# 4            Alto Longá        541              351
# ..                  ...        ...              ...
# 219  Vila Nova do Piauí        123              360
# 220       Várzea Branca        148              337
# 221       Várzea Grande        334              368
# 222         Wall Ferraz        329              313
# 223         Água Branca       1277              370
#
#      estimated_population_2019  estimated_population  city_ibge_code  \
# 0                       7084.0                7102.0       2200053.0
# 1                       5139.0                5131.0       2200103.0
# 2                       7651.0                7665.0       2200251.0
# 3                       4915.0                4918.0       2200277.0
# 4                      14304.0               14339.0       2200301.0
# ..                         ...                   ...             ...
# 219                     2971.0                2952.0       2211605.0
# 220                     4947.0                4938.0       2211357.0
# 221                     4391.0                4386.0       2211407.0
# 222                     4462.0                4471.0       2211704.0
# 223                    17411.0               17470.0       2200202.0
#
#      confirmed_per_100k_inhabitants  death_rate  latitude  longitude
# 0                        2464.09462      0.0057 -8.219542 -41.083059
# 1                        6470.47359      0.0090 -5.796784 -42.660513
# 2                        3339.85649      0.0352 -7.009095 -40.939675
# 3                        9353.39569      0.0109 -7.244014 -40.860230
# 4                        3772.92698      0.0240 -5.254905 -42.207239
# ..                              ...         ...       ...        ...
# 219                      4166.66667      0.0081 -7.142922 -40.937856
# 220                      2997.16484      0.0608 -9.237188 -42.964378
# 221                      7615.13908      0.0000 -6.546083 -42.248040
# 222                      7358.53277      0.0091 -7.233920 -41.911407
# 223                      7309.67373      0.0439 -5.891392 -42.636115
#
# [224 rows x 10 columns]

# %%
data = data.drop('city', axis=1)

# %%
data
# Out:
#      confirmed  order_for_place  estimated_population_2019  \
# 0          175              329                     7084.0
# 1          332              321                     5139.0
# 2          256              335                     7651.0
# 3          460              317                     4915.0
# 4          541              351                    14304.0
# ..         ...              ...                        ...
# 219        123              360                     2971.0
# 220        148              337                     4947.0
# 221        334              368                     4391.0
# 222        329              313                     4462.0
# 223       1277              370                    17411.0
#
#      estimated_population  city_ibge_code  confirmed_per_100k_inhabitants  \
# 0                  7102.0       2200053.0                      2464.09462
# 1                  5131.0       2200103.0                      6470.47359
# 2                  7665.0       2200251.0                      3339.85649
# 3                  4918.0       2200277.0                      9353.39569
# 4                 14339.0       2200301.0                      3772.92698
# ..                    ...             ...                             ...
# 219                2952.0       2211605.0                      4166.66667
# 220                4938.0       2211357.0                      2997.16484
# 221                4386.0       2211407.0                      7615.13908
# 222                4471.0       2211704.0                      7358.53277
# 223               17470.0       2200202.0                      7309.67373
#
#      death_rate  latitude  longitude
# 0        0.0057 -8.219542 -41.083059
# 1        0.0090 -5.796784 -42.660513
# 2        0.0352 -7.009095 -40.939675
# 3        0.0109 -7.244014 -40.860230
# 4        0.0240 -5.254905 -42.207239
# ..          ...       ...        ...
# 219      0.0081 -7.142922 -40.937856
# 220      0.0608 -9.237188 -42.964378
# 221      0.0000 -6.546083 -42.248040
# 222      0.0091 -7.233920 -41.911407
# 223      0.0439 -5.891392 -42.636115
#
# [224 rows x 9 columns]

# %% [markdown]
# ## Dados de treino e teste

# %%
X_train, X_test, y_train, y_test = train_test_split(data, data_alvo, test_size = 0.2,random_state=1, shuffle=True)

# %% [markdown]
# ## Feature Scaling

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
print(X_train)
# Out:
# [[-0.16526711  0.75092493 -0.15927876 ... -0.39194614 -1.37497595
#   -0.11785493]
#  [-0.1220363  -1.57274837 -0.16359189 ... -0.60193695 -0.48330021
#   -1.50238092]
#  [-0.12187852  0.89392021 -0.16209235 ... -1.11620016  0.08613273
#    0.15298155]
#  ...
#  [-0.13560509  0.32193909 -0.12324324 ...  0.61943818 -0.14702471
#    0.69956309]
#  [-0.14238949 -0.10704675 -0.1837353  ... -0.48622773  0.78774665
#    0.43730021]
#  [-0.10483864  0.03594853 -0.06632227 ... -0.14767111  1.24114717
